# %%
from a110_train import *

main()
# Out:
# ************************************************************
# YOLO_TYPE = yolov3
# TRAIN_YOLO_TINY = False
# Darknet_weights = model_data/yolov3.weights
# ************************************************************
#
# GPUs [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# skipping conv2d_74
# skipping conv2d_66
# skipping conv2d_58
# epoch: 0 step:    2/250, lr:0.000000, giou_loss:  19.52, conf_loss:1620.62, prob_loss: 127.66, total_loss:1767.80
# epoch: 0 step:    3/250, lr:0.000001, giou_loss:  20.75, conf_loss:1119.03, prob_loss: 120.48, total_loss:1260.25
# epoch: 0 step:    4/250, lr:0.000001, giou_loss:  18.86, conf_loss:1117.76, prob_loss: 103.93, total_loss:1240.55
# epoch: 0 step:    5/250, lr:0.000001, giou_loss:  21.37, conf_loss:1116.02, prob_loss: 114.14, total_loss:1251.53
# epoch: 0 step:    6/250, lr:0.000001, giou_loss:  21.41, conf_loss:1122.15, prob_loss: 123.11, total_loss:1266.66
# ...
