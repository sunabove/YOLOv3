# %%
from train import *

main()
# Out:
# ************************************************************
# YOLO_TYPE = yolov3
# Darknet_weights = model_data/yolov3.weights
# ************************************************************
#
# GPUs [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# skipping conv2d_74
# skipping conv2d_66
# skipping conv2d_58
# epoch: 0 step:    2/250, lr:0.000000, giou_loss:  22.85, conf_loss:1755.20, prob_loss: 146.17, total_loss:1924.23
# epoch: 0 step:    3/250, lr:0.000001, giou_loss:  15.42, conf_loss:1184.86, prob_loss: 103.64, total_loss:1303.93
# epoch: 0 step:    4/250, lr:0.000001, giou_loss:  15.08, conf_loss:1180.73, prob_loss: 100.35, total_loss:1296.16
# epoch: 0 step:    5/250, lr:0.000001, giou_loss:  18.90, conf_loss:1184.01, prob_loss: 125.11, total_loss:1328.02
# epoch: 0 step:    6/250, lr:0.000001, giou_loss:  18.95, conf_loss:1185.07, prob_loss: 124.59, total_loss:1328.61
# ...
